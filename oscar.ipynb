# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('matriculados_limpia.csv')
df.head()
# Out:
#    YEAR  SEMESTRE TIPO_NIVEL     NIVEL        DEP_NAC       CIU_NAC  \
# 0  2019         1   Pregrado  Pregrado  BOGOTÁ, D. C.  BOGOTÁ, D.C.
# 1  2019         1   Pregrado  Pregrado   CUNDINAMARCA    FACATATIVÁ
# 2  2019         1   Pregrado  Pregrado  BOGOTÁ, D. C.  BOGOTÁ, D.C.
# 3  2019         1   Pregrado  Pregrado  BOGOTÁ, D. C.  BOGOTÁ, D.C.
# 4  2019         1   Pregrado  Pregrado  BOGOTÁ, D. C.  BOGOTÁ, D.C.
#
#    LON_CIU_NAC  LAT_CIU_NAC       DEP_PROC      CIU_PROC  LON_CIU_PROC  \
# 0   -74.113919     4.624575  BOGOTÁ, D. C.  BOGOTÁ, D.C.    -74.113919
# 1   -74.351015     4.812242   CUNDINAMARCA    FACATATIVÁ    -74.351015
# 2   -74.113919     4.624575  BOGOTÁ, D. C.  BOGOTÁ, D.C.    -74.113919
# 3   -74.113919     4.624575  BOGOTÁ, D. C.  BOGOTÁ, D.C.    -74.113919
# 4   -74.113919     4.624575  BOGOTÁ, D. C.  BOGOTÁ, D.C.    -74.113919
#
#    LAT_CIU_PROC CODS_NAC NACIONALIDAD  EDAD     SEXO    ESTRATO TIPO_COL  PBM  \
# ...

# %%
df.columns
# Out:
# Index(['YEAR', 'SEMESTRE', 'TIPO_NIVEL', 'NIVEL', 'DEP_NAC', 'CIU_NAC',
#        'LON_CIU_NAC', 'LAT_CIU_NAC', 'DEP_PROC', 'CIU_PROC', 'LON_CIU_PROC',
#        'LAT_CIU_PROC', 'CODS_NAC', 'NACIONALIDAD', 'EDAD', 'SEXO', 'ESTRATO',
#        'TIPO_COL', 'PBM', 'MAT_PVEZ', 'SEDE_NOMBRE_ADM', 'SEDE_NOMBRE_MAT',
#        'ADM_PEAMA_ANDINA', 'TIPO_ADM', 'PAES', 'PEAMA', 'MOV_PEAMA',
#        'CONVENIO', 'TIP_CONVENIO', 'FACULTAD', 'SNIES_PROGRA', 'PROGRAMA',
#        'AREAC_SNIES', 'CA_CINE', 'CD_CINE', 'AREA_CINE', 'Segmento'],
#       dtype='object')

# %% [markdown]
# 1. **YEAR**
#    - Descripción: Año de disponibilidad de los datos - disponible desde el año 2018.
#    - Tipo: Número.
#
# 2. **SEMESTRE**
#    - Descripción: Semestre de disponibilidad de los datos.
#    - Tipo: Número.
#
# 3. **TIPO_NIVEL**
#    - Descripción: Tipo nivel de formación del estudiante matriculado.
#    - Tipo: Texto.
#
# 4. **NIVEL**
#    - Descripción: Nivel de formación del estudiante matriculado.
#    - Tipo: Texto.
#
# 5. **DEP_NAC**
#    - Descripción: Departamento de nacimiento del estudiante matriculado.
#    - Tipo: Texto.
#
# 6. **CIU_NAC**
#    - Descripción: Municipio de nacimiento del estudiante graduado.
#    - Tipo: Texto.
#
# 7. **DEP_PROC**
#    - Descripción: Nombre departamento de procedencia de estudiante matriculado.
#    - Tipo: Texto.
#
# 8. **CIU_PROC**
#    - Descripción: Municipio de procedencia del estudiante matriculado.
#    - Tipo: Texto.
#
# 9. **CODS_NAC**
#    - Descripción: Código Alpha 3 ISO 3166 del país de nacimiento del estudiante matriculado.
#    - Tipo: Texto.
#
# 10. **NACIONALIDAD**
#     - Descripción: Nacionalidad del estudiante matriculado.
#     - Tipo: Texto.
#
# 11. **EDAD**
#     - Descripción: Edad (en años) del estudiante matriculado.
#     - Tipo: Número.
#
# 12. **SEXO**
#     - Descripción: Sexo biológico del estudiante matriculado.
#     - Tipo: Texto.
#
# 13. **ESTRATO**
#     - Descripción: Estrato socioeconómico del estudiante matriculado.
#     - Tipo: Texto.
#
# 14. **TIPO_COL**
#     - Descripción: Tipología del colegio del estudiante matriculado.
#     - Tipo: Texto.
#
# 15. **PBM**
#     - Descripción: Puntaje Básico de Matrícula PBM del estudiante matriculado.
#     - Tipo: Número.
#
# 16. **MAT_PVEZ**
#     - Descripción: Estudiantes matriculados por primera vez.
#     - Tipo: Texto.
#
# 17. **SEDE_NOMBRE_ADM**
#     - Descripción: Nombre de la sede de admisión en la UNAL del estudiante matriculado.
#     - Tipo: Texto.
#
# 18. **SEDE_NOMBRE_MAT**
#     - Descripción: Nombre de la sede de la UNAL en la que se encuentra el estudiante matriculado.
#     - Tipo: Texto.
#
# 19. **ADM_PEAMA_ANDINA**
#     - Descripción: Sede ANDINA de admisión de los estudiantes admitidos a través del programa PEAMA.
#     - Tipo: Texto.
#
# 20. **TIPO_ADM**
#     - Descripción: Tipo de admisión del estudiante matriculado.
#     - Tipo: Texto.
#
# 21. **PAES**
#     - Descripción: Estudiantes matriculados admitidos a través del programa PAES.
#     - Tipo: Texto.
#
# 22. **PEAMA**
#     - Descripción: Estudiantes matriculados admitidos a través del programa PEAMA.
#     - Tipo: Texto.
#
# 23. **MOV_PEAMA**
#     - Descripción: Fase de movilidad de los estudiantes matriculados admitidos a través del programa PEAMA.
#     - Tipo: Texto.
#
# 24. **CONVENIO**
#     - Descripción: Estudiantes matriculados admitidos a través de convenios (aplica para postgrado).
#     - Tipo: Texto.
#
# 25. **TIP_CONVENIO**
#     - Descripción: Tipología de estudiantes matriculados admitidos a través de convenios (aplica para postgrado).
#     - Tipo: Texto.
#
# 26. **FACULTAD**
#     - Descripción: Facultad en la que se encuentra matriculado el estudiante.
#     - Tipo: Texto.
#
# 27. **SNIES_PROGRA**
#     - Descripción: Código SNIES del programa en el que se encuentra matriculado el estudiante.
#     - Tipo: Número.
#
# 28. **PROGRAMA**
#     - Descripción: Nombre programa académico en el que se encuentra matriculado el estudiante.
#     - Tipo: Texto.
#
# 29. **AREAC_SNIES**
#     - Descripción: Área SNIES a la que se encuentra adscrito el programa académico en el que se encuentra matriculado el estudiante.
#     - Tipo: Texto.
#
# 30. **CA_CINE**
#     - Descripción: Código amplio área de conocimiento CINE del programa en el que se encuentra el estudiante matriculado.
#     - Tipo: Número.
#
# 31. **CD_CINE**
#     - Descripción: Código detallado área de conocimiento CINE del programa en el que se encuentra el estudiante matriculado.
#     - Tipo: Número.
#
# 32. **AREA_CINE**
#     - Descripción: Área de conocimiento CINE del programa académico en el que se encuentra el estudiante matriculado.
#     - Tipo: Texto.
#
# 33. **Segmento**
#     - Descripción: No se proporciona una descripción en la lista original.
#     - Tipo: No se especifica.
#
# ## Datos Geograficos
#
# 34. **LON_CIU_NAC**
#    - Descripción: Longitud ubicación municipio de nacimiento del estudiante matriculado.
#    - Tipo: Número.
#
# 35. **LAT_CIU_NAC**
#    - Descripción: Latitud ubicación municipio de nacimiento del estudiante matriculado.
#    - Tipo: Número.
#
# 36. **LON_CIU_PROC**
#    - Descripción: Longitud de ubicación del municipio de procedencia del estudiante matriculado.
#    - Tipo: Número.
#
# 37. **LAT_CIU_PROC**
#    - Descripción: Latitud de ubicación del municipio de procedencia del estudiante matriculado.
#    - Tipo: Número.

# %% [markdown]
# # Análiss Datos Cuantitativos

# %%
quantitative_columns = df.select_dtypes(include=['int64', 'float64']).columns
quantitative_columns
# Out:
# Index(['YEAR', 'SEMESTRE', 'LON_CIU_NAC', 'LAT_CIU_NAC', 'LON_CIU_PROC',
#        'LAT_CIU_PROC', 'EDAD', 'PBM', 'SNIES_PROGRA', 'CA_CINE', 'CD_CINE'],
#       dtype='object')

# %% [markdown]
# Quitamos los datos referentes a ubocación geografica, esos van en un analisis separado

# %%
columns_to_remove = ['LON_CIU_NAC', 'LAT_CIU_NAC', 'LON_CIU_PROC', 'LAT_CIU_PROC']


df_quantitative = df[quantitative_columns].drop(columns=columns_to_remove)
df_quantitative.head()
# Out:
#    YEAR  SEMESTRE  EDAD  PBM  SNIES_PROGRA  CA_CINE  CD_CINE
# 0  2019         1    46   11            24        8      811
# 1  2019         1    27   23            17        4      421
# 2  2019         1    29   18            17        4      421
# 3  2019         1    24   70            18        3      311
# 4  2019         1    24   12            18        3      311

# %%
df_quantitative.describe()
# Out:
#                 YEAR       SEMESTRE           EDAD            PBM  \
# count  547934.000000  547934.000000  547934.000000  547934.000000
# mean     2021.045307       1.509479      23.499135      25.246730
# std         1.411641       0.499911       5.563153      23.374998
# min      2019.000000       1.000000      14.000000      -1.000000
# 25%      2020.000000       1.000000      20.000000       7.000000
# 50%      2021.000000       2.000000      22.000000      17.000000
# 75%      2022.000000       2.000000      25.000000      42.000000
# max      2023.000000       2.000000      79.000000     100.000000
#
#         SNIES_PROGRA        CA_CINE        CD_CINE
# count  547934.000000  547934.000000  547934.000000
# mean    13877.026514       5.871963     595.498107
# std     28124.279432       2.192800     234.998931
# min         1.000000       1.000000     -89.000000
# 25%        25.000000       4.000000     413.000000
# 50%       123.000000       7.000000     711.000000
# ...

# %%
# Verificar si hay datos nulos en df_quantitative
nulos_df_quantitative = df_quantitative.isnull().sum()
print(nulos_df_quantitative)
# Out:
# YEAR            0
# SEMESTRE        0
# EDAD            0
# PBM             0
# SNIES_PROGRA    0
# CA_CINE         0
# CD_CINE         0
# dtype: int64

# %% [markdown]
# No hay datos nulos

# %% [markdown]
# # Limpieza de Datos
# Vamos a arreglar los errores de los nombres del PROGRAMA apoyandonos del código SNIES_PROGRAM
# vamos a leer un archivo progrmaas.csv que contiene lso snies con su programa correspondiente
# png)

# %%
# Leer el archivo programas.csv
programas_df = pd.read_csv('programas.csv')

# Renombrar las columnas para que coincidan con las del dataframe df
programas_df.rename(columns={'CÓDIGO_SNIES_DEL_PROGRAMA': 'SNIES_PROGRA', 'NOMBRE_DEL_PROGRAMA': 'PROGRAMA'}, inplace=True)

# Actualizar el nombre del programa en el dataframe df
df = df.merge(programas_df[['SNIES_PROGRA', 'PROGRAMA']], on='SNIES_PROGRA', how='left', suffixes=('', '_csv'))

# Reemplazar los valores de la columna PROGRAMA con los valores de la columna PROGRAMA_csv si no son nulos
df['PROGRAMA'] = df['PROGRAMA_csv'].combine_first(df['PROGRAMA'])
df.drop(columns=['PROGRAMA_csv'], inplace=True)

df['PROGRAMA'].unique()
# Out:
# array(['INGENIERIA AGRICOLA', 'DERECHO', 'ECONOMIA', 'QUIMICA',
#        'MATEMATICAS', 'INGENIERIA ELECTRICA', 'INGENIERIA INDUSTRIAL',
#        'INGENIERIA CIVIL', 'INGENIERÍA DE SISTEMAS Y COMPUTACIÓN',
#        'INGENIERIA ELECTRONICA', 'ZOOTECNIA', 'INGENIERIA QUIMICA',
#        'CINE Y TELEVISION', 'PSICOLOGIA', 'DISEÑO INDUSTRIAL',
#        'INGENIERIA MECANICA', 'ODONTOLOGIA', 'INGENIERIA MECATRONICA',
#        'ESTUDIOS LITERARIOS', 'BIOLOGIA', 'INGENIERIA AGRONOMICA',
#        'TRABAJO SOCIAL', 'FISIOTERAPIA', 'CONTADURIA PUBLICA',
#        'DISEÑO GRAFICO', 'ARQUITECTURA', 'NUTRICION Y DIETETICA',
#        'SOCIOLOGIA', 'FARMACIA', 'CIENCIA POLÍTICA',
#        'MEDICINA VETERINARIA', 'ADMINISTRACION DE EMPRESAS', 'ENFERMERIA',
#        'ARTES PLASTICAS', 'ANTROPOLOGIA', 'GEOGRAFIA', 'ESTADISTICA',
#        'FILOSOFIA', 'MAESTRIA EN DISCAPACIDAD E INCLUSION SOCIAL',
#        'FISICA', 'MAESTRÍA EN DERECHO',
#        'MAESTRIA EN INGENIERIA - INGENIERIA QUIMICA',
# ...

# %% [markdown]
# el minimo de CD_CINE es -89 lo cual parece un error (verifiquemos los registros)

# %%
df_cd_cine_neg_89 = df[df['CD_CINE'] == -89]
df_cd_cine_neg_89
# Out:
#         YEAR  SEMESTRE TIPO_NIVEL     NIVEL        DEP_NAC        CIU_NAC  \
# 81      2019         1   Pregrado  Pregrado           META  VILLAVICENCIO
# 240     2019         1   Pregrado  Pregrado      SANTANDER    BUCARAMANGA
# 557     2019         1   Pregrado  Pregrado  BOGOTÁ, D. C.   BOGOTÁ, D.C.
# 600     2019         1   Pregrado  Pregrado   CUNDINAMARCA     FUSAGASUGÁ
# 605     2019         1   Pregrado  Pregrado  BOGOTÁ, D. C.   BOGOTÁ, D.C.
# ...      ...       ...        ...       ...            ...            ...
# 541662  2023         2   Pregrado  Pregrado  BOGOTÁ, D. C.   BOGOTÁ, D.C.
# 541673  2023         2   Pregrado  Pregrado  BOGOTÁ, D. C.   BOGOTÁ, D.C.
# 541699  2023         2   Pregrado  Pregrado  BOGOTÁ, D. C.   BOGOTÁ, D.C.
# 541749  2023         2   Pregrado  Pregrado       CASANARE          YOPAL
# 541750  2023         2   Pregrado  Pregrado  BOGOTÁ, D. C.   BOGOTÁ, D.C.
#
#         LON_CIU_NAC  LAT_CIU_NAC       DEP_PROC      CIU_PROC  LON_CIU_PROC  \
# ...

# %% [markdown]
# Veamos que programas solo tienen el valor -89 o más valores

# %%
unique_cd_cine_per_snies = df.groupby('SNIES_PROGRA')['CD_CINE'].unique().reset_index()
# Filtrar los registros que tienen valores negativos o más de dos valores únicos
filtered_cd_cine = unique_cd_cine_per_snies[
    unique_cd_cine_per_snies['CD_CINE'].apply(lambda x: any(val < 0 for val in x) or len(x) > 2)
]
filtered_cd_cine
# Out:
#      SNIES_PROGRA CD_CINE
# 3               4   [-89]
# 155         16904   [-89]
# 406        106341   [-89]
# 446        107447   [-89]
# 458        110177   [-89]

# %%
snies_progra_resultantes = filtered_cd_cine['SNIES_PROGRA'].tolist()
snies_progra_resultantes
# Out:
# [4, 16904, 106341, 107447, 110177]

# %% [markdown]
# Corregimos 101984 con su valor respecttvo

# %%
df.loc[df['SNIES_PROGRA'] == 101984, 'CD_CINE'] = 711

# %%
# Agrupar por SNIES_PROGRA y contar los valores únicos de CD_CINE en cada grupo
cd_cine_unique_per_snies = df.groupby('SNIES_PROGRA')['CD_CINE'].nunique().reset_index()

# Verificar si todos los SNIES_PROGRA tienen un único valor de CD_CINE
snies_determina_cd_cine = cd_cine_unique_per_snies['CD_CINE'].max() == 1

print(f"¿SNIES_PROGRA determina a CD_CINE? {snies_determina_cd_cine}")
# Out:
# ¿SNIES_PROGRA determina a CD_CINE? True

# %%
# Filtrar los datos para excluir los registros con CD_CINE igual a -89
df_filtered = df[df['CD_CINE'] != -89]

# Agrupar por CD_CINE y contar los valores únicos de CA_CINE en cada grupo
ca_cine_unique_per_cd_cine = df_filtered.groupby('CD_CINE')['CA_CINE'].nunique().reset_index()

# Verificar si todos los CD_CINE tienen un único valor de CA_CINE
cd_cine_determina_ca_cine = ca_cine_unique_per_cd_cine['CA_CINE'].max() == 1

print(f"¿CD_CINE determina a CA_CINE sin contar los valores con -89? {cd_cine_determina_ca_cine}")
# Out:
# ¿CD_CINE determina a CA_CINE sin contar los valores con -89? True

# %% [markdown]
# Como CD_CINE determina a CA_CINE, podemos buscar segun los CA_CINE cual es el codigo correspondiente si existe

# %%
# Filtrar los programas según los SNIES en snies_progra_resultantes
programas_filtrados = programas_df[programas_df['SNIES_PROGRA'].isin(snies_progra_resultantes)]

programas_filtrados
# Out:
#     CÓDIGO_INSTITUCIÓN_PADRE CÓDIGO_INSTITUCIÓN  \
# 6                       1101               1101
# 11                      1101               1101
# 336                     1101               1102
# 478                     1101               1103
# 559                     1101               1104
#
#                    NOMBRE_INSTITUCIÓN ESTADO_INSTITUCIÓN CARÁCTER_ACADÉMICO  \
# 6    UNIVERSIDAD NACIONAL DE COLOMBIA             Activa        Universidad
# 11   UNIVERSIDAD NACIONAL DE COLOMBIA             Activa        Universidad
# 336  UNIVERSIDAD NACIONAL DE COLOMBIA             Activa        Universidad
# 478  UNIVERSIDAD NACIONAL DE COLOMBIA             Activa        Universidad
# 559  UNIVERSIDAD NACIONAL DE COLOMBIA             Activa        Universidad
#
#       SECTOR  REGISTRO_UNICO  SNIES_PROGRA  CÓDIGO_ANTERIOR_ICFES  \
# 6    Oficial             NaN      106341.0           1.063410e+05
# 11   Oficial             NaN           4.0           1.101474e+20
# ...

# %% [markdown]
# Como son pocos valores se puede buscar si CD_CINE correspondiente o similar en internet
#
# 106341 = 619
#
# 107447 = 619
#
# 110177 = 619
#
# 16904  = 721
#
# 4      = 211

# %%
df.loc[df['SNIES_PROGRA'] == 106341, 'CD_CINE'] = 619
df.loc[df['SNIES_PROGRA'] == 107447, 'CD_CINE'] = 619
df.loc[df['SNIES_PROGRA'] == 110177, 'CD_CINE'] = 619
df.loc[df['SNIES_PROGRA'] == 16904, 'CD_CINE'] = 721
df.loc[df['SNIES_PROGRA'] == 4, 'CD_CINE'] = 211

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filtrar los valores de CD_CINE que no son -89
#df_quantitative_filtered = df_quantitative[df_quantitative['CD_CINE'] != -89]

# Calcular la matriz de correlación
correlation_matrix_filtered = df_quantitative_filtered.corr()

# Crear el mapa de calor
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_filtered, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Mapa de Calor de Correlación entre Variables Cuantitativas (Excluyendo CD_CINE = -89)')
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Ajustar los valores de los histogramas para las variables discretas
df_quantitative['YEAR'].value_counts().sort_index().plot(kind='bar', ax=axes[0], title='Distribución de Años')
df_quantitative['SEMESTRE'].value_counts().sort_index().plot(kind='bar', ax=axes[1], title='Distribución de Semestres')

plt.tight_layout()
plt.show()

# Graficar histogramas para las demás variables cuantitativas
df_quantitative.drop(columns=['YEAR', 'SEMESTRE']).hist(bins=30, figsize=(15, 10), layout=(3, 3))
plt.suptitle('Histogramas de Variables Cuantitativas')
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Crear un boxplot para cada columna de df_quantitative
df_quantitative.plot(kind='box', subplots=True, layout=(8, 2), figsize=(20, 20), sharex=False, sharey=False)
plt.suptitle('Boxplots de Variables Cuantitativas')
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Calcular los cuartiles y el rango intercuartílico (IQR)
Q1 = df_quantitative.quantile(0.25)
Q3 = df_quantitative.quantile(0.75)
IQR = Q3 - Q1

# Identificar los datos atípicos
outliers = ((df_quantitative < (Q1 - 1.5 * IQR)) | (df_quantitative > (Q3 + 1.5 * IQR)))

# Mostrar los datos atípicos y la cantidad de registros
for column in df_quantitative.columns:
    outlier_data = df_quantitative[column][outliers[column]]
    print(f"Columna: {column}")
    print(outlier_data.value_counts())
    print("\n")
# Out:
# Columna: YEAR
# Series([], Name: count, dtype: int64)
#
#
# Columna: SEMESTRE
# Series([], Name: count, dtype: int64)
#
#
# Columna: EDAD
# EDAD
# 33    5172
# 34    4330
# 35    3582
# 36    3107
# 37    2720
# 38    2356
# 39    2045
# 40    1793
# 41    1523
# 42    1297
# 43    1103
# 44     914
# 45     785
# 46     664
# 47     584
# 49     516
# 48     498
# 50     416
# 51     374
# 52     323
# 53     270
# 54     234
# 55     211
# 56     175
# 57     156
# 58     120
# 59      94
# 60      86
# 62      61
# 64      60
# 63      56
# 61      51
# 65      45
# 66      38
# 67      37
# 68      30
# 71      15
# 70      14
# 69      13
# 72       8
# 74       6
# 73       4
# 75       2
# 79       2
# 77       1
# 78       1
# Name: count, dtype: int64
#
#
# Columna: PBM
# PBM
# 100    1284
# 96      104
# 95      101
# 97      101
# 98       57
# 99       13
# Name: count, dtype: int64
#
#
# Columna: SNIES_PROGRA
# SNIES_PROGRA
# 106661    10318
# 55189      4008
# ...

# %%
# Excluir los valores de PBM que son -1
df_filtered_pbm = df[df['PBM'] != -1]

# Seleccionar los top 10 programas con más estudiantes
top_programas = df_filtered_pbm['PROGRAMA'].value_counts().head(10).index.tolist()
df_top = df_filtered_pbm[df_filtered_pbm['PROGRAMA'].isin(top_programas)]

# Boxplot del PBM por programa
plt.figure(figsize=(12, 8))
sns.boxplot(x='PROGRAMA', y='PBM', data=df_top)
plt.title('Distribución del PBM por Programa Académico (Top 10)')
plt.xticks(rotation=45)
plt.xlabel('Programa')
plt.ylabel('PBM')
plt.show()

# %%
# Agrupar por SNIES_PROGRA y calcular el promedio de PBM
pbm_promedio_snies = df.groupby('SNIES_PROGRA')['PBM'].mean().reset_index()

# Unir con el dataframe original para obtener el nombre del programa
pbm_promedio_snies = pbm_promedio_snies.merge(df[['SNIES_PROGRA', 'PROGRAMA']].drop_duplicates(), on='SNIES_PROGRA')

# Ordenar por PBM promedio
pbm_promedio_snies = pbm_promedio_snies.sort_values('PBM', ascending=False)

# Mostrar los 10 primeros registros
print("Los 10 primeros registros:")
pbm_promedio_snies.head(10)
# Out:
# Los 10 primeros registros:
#      SNIES_PROGRA        PBM                    PROGRAMA
# 5               6  43.104028           CINE Y TELEVISION
# 406        106341  40.855696  CIENCIAS DE LA COMPUTACIÓN
# 8               9  40.119542                    MEDICINA
# 117          2497  39.784711             ARTES PLASTICAS
# 415        106654  39.219724         ESTUDIOS LITERARIOS
# 17             18  39.199297                    ECONOMIA
# 30             33  39.198192                      FISICA
# 25             28  38.924741         INGENIERIA MECANICA
# 3               4  38.915531              DISEÑO GRAFICO
# 26             29  38.679779          INGENIERIA QUIMICA

# %%
# Mostrar los 10 últimos registros
print("\nLos 10 últimos registros:")
pbm_promedio_snies.tail(10)
# Out:
# Los 10 últimos registros:
#      SNIES_PROGRA  PBM                                        PROGRAMA
# 218         19913 -1.0     MAESTRIA EN INGENIERIA - TELECOMUNICACIONES
# 219         19914 -1.0     MAESTRIA EN INGENIERIA -INGENIERIA AGRICOLA
# 188         16955 -1.0                     ESPECIALIDAD EN HEMATOLOGIA
# 189         17906 -1.0                      MAESTRIA EN ADMINISTRACION
# 190         19860 -1.0                           DOCTORADO EN HISTORIA
# 191         19863 -1.0                             MAESTRIA EN HABITAT
# 192         19864 -1.0              MAESTRIA EN INGENIERIA - GEOTECNIA
# 193         19865 -1.0  MAESTRIA EN INGENIERIA - MATERIALES Y PROCESOS
# 194         19866 -1.0   MAESTR¿A EN INGENIER¿A - INGENIER¿A - QU¿MICA
# 215         19910 -1.0                             MAESTRÍA EN DERECHO

# %%
# Obtener los valores únicos de PBM para cada programa
pbm_unicos_por_programa = df[df['PBM'] == -1].groupby('SNIES_PROGRA')['PBM'].unique()

# Filtrar los programas que solo tienen -1 como valor único
programas_solo_menos_uno = pbm_unicos_por_programa[pbm_unicos_por_programa.apply(lambda x: len(x) == 1 and x[0] == -1)].index.tolist()
pbm_unicos_por_programa
# Out:
# SNIES_PROGRA
# 12        [-1]
# 14        [-1]
# 19        [-1]
# 27        [-1]
# 38        [-1]
#           ...
# 110724    [-1]
# 110725    [-1]
# 110726    [-1]
# 110727    [-1]
# 110738    [-1]
# Name: PBM, Length: 370, dtype: object

# %%
# Excluir los valores de PBM que son -1
df_quantitative_filtered = df_quantitative[df_quantitative['PBM'] != -1]

# Calcular el PBM promedio por edad
pbm_por_edad = df_quantitative_filtered.groupby('EDAD')['PBM'].mean().reset_index()

# Gráfico de líneas
sns.lineplot(x='EDAD', y='PBM', data=pbm_por_edad, marker='o', color='green')
plt.title('PBM Promedio por Edad')
plt.xlabel('Edad')
plt.ylabel('PBM Promedio')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Filtrar los datos para excluir los valores de PBM que son -1
df_filtered_pbm = df[df['PBM'] != -1]

# Crear la gráfica de violín
plt.figure(figsize=(12, 8))
sns.violinplot(x='SEXO', y='PBM', data=df_filtered_pbm, split=True, palette='muted')
plt.title('Distribución de PBM por Género')
plt.xlabel('Género')
plt.ylabel('PBM')
plt.legend(title='Edad', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# /tmp/ipykernel_9996/336031844.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='SEXO', y='PBM', data=df_filtered_pbm, split=True, palette='muted')
# /tmp/ipykernel_9996/336031844.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Edad', bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
#
plt.figure(figsize=(12, 8))
sns.violinplot(x='SEXO', y='EDAD', data=df_filtered_pbm, split=True, palette='muted')
plt.title('Distribución de Edad por Género')
plt.xlabel('Género')
plt.ylabel('Edad')
plt.legend(title='Edad', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# /tmp/ipykernel_9996/1215899102.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='SEXO', y='EDAD', data=df_filtered_pbm, split=True, palette='muted')
# /tmp/ipykernel_9996/1215899102.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Edad', bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# ## Distribución Temporal (YEAR y SEMESTRE)
# Objetivo: Analizar cómo varía la cantidad de estudiantes y el PBM promedio a lo largo de los años y semestres.

# %%
# Excluir los valores de PBM que son -1
df_filtered_pbm = df[df['PBM'] != -1]

# PBM promedio por año y semestre
pbm_data = df_filtered_pbm.groupby(['YEAR', 'SEMESTRE'])['PBM'].mean().reset_index()

# Crear el gráfico de líneas
plt.figure(figsize=(10, 6))
sns.lineplot(data=pbm_data, x='YEAR', y='PBM', hue='SEMESTRE', marker='o')
plt.title('PBM Promedio por Año y Semestre')
plt.xlabel('Año')
plt.ylabel('PBM Promedio')
plt.grid(True)
plt.show()

# %% [markdown]
# # Cruce de Datos Aspirantes y Matriculados

# %%
df_aspirantes = pd.read_csv('Aspirantes_y_Admitidos_mod.csv')
df_matriculados = pd.read_csv('matriculados_limpia.csv')

# Encontrar las columnas comunes
common_columns = df_matriculados.columns.intersection(df_aspirantes.columns)
common_columns_list = common_columns.tolist()

# Mostrar las columnas comunes
print("Columnas comunes:", common_columns_list)
# Out:
# Columnas comunes: ['YEAR', 'SEMESTRE', 'TIPO_NIVEL', 'NIVEL', 'DEP_NAC', 'CIU_NAC', 'LON_CIU_NAC', 'LAT_CIU_NAC', 'CODS_NAC', 'NACIONALIDAD', 'EDAD', 'SEXO', 'ESTRATO', 'PAES', 'PEAMA', 'SNIES_PROGRA', 'PROGRAMA', 'AREAC_SNIES', 'CA_CINE', 'CD_CINE', 'AREA_CINE']

# %% [markdown]
# Vamos a dejar solo los aspirantes que pasaron la prueba, y en el mismo rango de fecha de los matriculados

# %%
# Verificar si cada columna común tiene datos en común
for column in common_columns_list:
    common_data = df_aspirantes_admitidos[column].isin(df_matriculados[column])
    print(f"Columna: {column}")
    print(f"Datos en común: {common_data.any()}")
    print("\n")
# Out:
# Columna: YEAR
# Datos en común: True
#
#
# Columna: SEMESTRE
# Datos en común: True
#
#
# Columna: TIPO_NIVEL
# Datos en común: True
#
#
# Columna: NIVEL
# Datos en común: True
#
#
# Columna: DEP_NAC
# Datos en común: True
#
#
# Columna: CIU_NAC
# Datos en común: True
#
#
# Columna: LON_CIU_NAC
# Datos en común: True
#
#
# Columna: LAT_CIU_NAC
# Datos en común: True
#
#
# Columna: CODS_NAC
# Datos en común: True
#
#
# Columna: NACIONALIDAD
# Datos en común: True
#
#
# Columna: EDAD
# Datos en común: True
#
#
# Columna: SEXO
# Datos en común: True
#
#
# Columna: ESTRATO
# Datos en común: True
#
#
# Columna: PAES
# Datos en común: True
#
#
# Columna: PEAMA
# Datos en común: True
#
#
# Columna: SNIES_PROGRA
# Datos en común: True
#
#
# Columna: PROGRAMA
# Datos en común: False
#
#
# Columna: AREAC_SNIES
# Datos en común: True
#
#
# Columna: CA_CINE
# Datos en común: True
#
#
# Columna: CD_CINE
# Datos en común: True
#
#
# Columna: AREA_CINE
# Datos en común: True

# %% [markdown]
# Como SNIES PROGRAMA determina a programa, es más confiable usarlo, y sacar programa del calculo ya que lso datos no son en común

# %%
# Quitar la columna 'PROGRAMA' de la lista common_columns_list
common_columns_list.remove('PROGRAMA')
print(common_columns_list)
# Out:
# ['YEAR', 'SEMESTRE', 'TIPO_NIVEL', 'NIVEL', 'DEP_NAC', 'CIU_NAC', 'LON_CIU_NAC', 'LAT_CIU_NAC', 'CODS_NAC', 'NACIONALIDAD', 'EDAD', 'SEXO', 'ESTRATO', 'PAES', 'PEAMA', 'SNIES_PROGRA', 'AREAC_SNIES', 'CA_CINE', 'CD_CINE', 'AREA_CINE']

# %%
df_aspirantes
# Out:
#         YEAR  SEMESTRE TIPO_NIVEL                   NIVEL       DEP_NAC  \
# 0       2019         1   Pregrado                Pregrado      AMAZONAS
# 1       2019         1   Pregrado                Pregrado      AMAZONAS
# 2       2019         1   Pregrado                Pregrado      AMAZONAS
# 3       2019         1   Pregrado                Pregrado      AMAZONAS
# 4       2019         1   Pregrado                Pregrado      AMAZONAS
# ...      ...       ...        ...                     ...           ...
# 508012  2024         1  Postgrado  Especialidades médicas        BOYACÁ
# 508013  2024         1  Postgrado         Especialización     SANTANDER
# 508014  2024         1  Postgrado                Maestría  CUNDINAMARCA
# 508015  2024         1  Postgrado  Especialidades médicas   BOGOTÁ D.C.
# 508016  2024         1  Postgrado  Especialidades médicas   BOGOTÁ D.C.
#
#              CIU_NAC  LON_CIU_NAC  LAT_CIU_NAC      DEP_RES       CIU_RES  \
# ...

# %%
# Filtrar los aspirantes que fueron admitidos
df_aspirantes_admitidos = df_aspirantes[df_aspirantes['ADMITIDO'] == 'Sí']

# Obtener los rangos de YEAR y SEMESTRE de los matriculados
year_min = df_matriculados['YEAR'].min()
year_max = df_matriculados['YEAR'].max()


# Filtrar los aspirantes admitidos para que estén dentro del rango de fechas de los matriculados
df_aspirantes_admitidos = df_aspirantes_admitidos[
    (df_aspirantes_admitidos['YEAR'] >= year_min) & 
    (df_aspirantes_admitidos['YEAR'] <= year_max) 
]
df_aspirantes_admitidos
# Out:
#         YEAR  SEMESTRE TIPO_NIVEL            NIVEL          DEP_NAC  \
# 66      2019         1   Pregrado         Pregrado         AMAZONAS
# 76      2019         1   Pregrado         Pregrado         AMAZONAS
# 103     2019         1   Pregrado         Pregrado         AMAZONAS
# 118     2019         1   Pregrado         Pregrado         AMAZONAS
# 120     2019         1   Pregrado         Pregrado         AMAZONAS
# ...      ...       ...        ...              ...              ...
# 453686  2023         2  Postgrado  Especialización           TOLIMA
# 453687  2023         2  Postgrado         Maestría          QUINDÍO
# 453688  2023         2  Postgrado         Maestría        ANTIOQUIA
# 453689  2023         2  Postgrado  Especialización  VALLE DEL CAUCA
# 453691  2023         2  Postgrado         Maestría          QUINDÍO
#
#             CIU_NAC  LON_CIU_NAC  LAT_CIU_NAC        DEP_RES       CIU_RES  \
# ...

# %% [markdown]
# # Código en SQL

# %%
import pandasql as psql

# Crear un ID para cada registro en df_matriculados
df_matriculados['id_matriculados'] = df_matriculados.index
df_aspirantes_admitidos['id_aspirantes'] = df_aspirantes_admitidos.index

# Realizar el merge (producto cruzado) usando una consulta SQL
query = """
SELECT 
    m.id_matriculados, 
    a.id_aspirantes, 
    m.YEAR, 
    m.SEMESTRE, 
    m.TIPO_NIVEL, 
    m.NIVEL, 
    m.DEP_NAC, 
    m.CIU_NAC, 
    m.LON_CIU_NAC, 
    m.LAT_CIU_NAC, 
    m.DEP_PROC, 
    m.CIU_PROC, 
    m.LON_CIU_PROC, 
    m.LAT_CIU_PROC, 
    m.CODS_NAC, 
    m.NACIONALIDAD, 
    m.EDAD, 
    m.SEXO, 
    m.ESTRATO, 
    m.TIPO_COL, 
    m.PBM, 
    m.MAT_PVEZ, 
    m.SEDE_NOMBRE_ADM, 
    m.SEDE_NOMBRE_MAT, 
    m.ADM_PEAMA_ANDINA, 
    m.TIPO_ADM, 
    m.PAES, 
    m.PEAMA, 
    m.MOV_PEAMA, 
    m.CONVENIO, 
    m.TIP_CONVENIO, 
    m.FACULTAD, 
    m.SNIES_PROGRA, 
    m.PROGRAMA as PROGRAMA_matriculados, 
    m.AREAC_SNIES, 
    m.CA_CINE, 
    m.CD_CINE, 
    m.AREA_CINE, 
    m.Segmento, 
    a.DEP_RES, 
    a.CIU_RES, 
    a.LON_CIU_RES, 
    a.LAT_CIU_RES, 
    a.DISCAPACIDAD, 
    a.TIPO_DISC, 
    a.TIPO_INS, 
    a.SNIES_SEDE, 
    a.INS_SEDE_NOMBRE, 
    a.PTOTAL, 
    a.ADMITIDO, 
    a.PROGRAMA as PROGRAMA_aspirantes, 
    a.MODALIDAD, 
    a.RANGO_ANO_TERMINACION
FROM 
    df_matriculados m
INNER JOIN 
    df_aspirantes_admitidos a
ON 
    """ + " AND ".join([f"m.{col} = a.{col}" for col in common_columns_list]) + """
"""

result = psql.sqldf(query, locals())

# Eliminar registros duplicados
result = result.drop_duplicates()

result.to_csv('cruce_aspirantes_matriculados.csv', index=False)

# %% [markdown]
# # Código en merge de pd

# %%
# Crear un ID para cada registro en df_matriculados
df_matriculados['id_matriculados'] = df_matriculados.index
df_aspirantes_admitidos['id_aspirantes'] = df_aspirantes_admitidos.index

# Realizar el merge (producto cruzado) usando pandas
result = pd.merge(
    df_matriculados,df_aspirantes_admitidos,
    on=common_columns_list,
    how='inner', 
    suffixes=('_matriculados','_aspirantes')
)
## elimina registros duplicados 
result = result.drop_duplicates()
# Reordenar las columnas para que id_matriculados y id_aspirantes estén al principio
column_order = ['id_matriculados', 'id_aspirantes'] + [col for col in result.columns if col not in ['id_matriculados', 'id_aspirantes']]
result = result[column_order]


result.to_csv('cruce_aspirantes_matriculados.csv', index=False)

# %%
# Número de registros en df_matriculados
num_matriculados = df_matriculados.shape[0]

# Número de registros únicos en el cruce usando id_matriculados
num_cruce_unicos = result['id_matriculados'].nunique()

print(f"Número de registros en df_matriculados: {num_matriculados}")
print(f"Número de registros únicos en el cruce: {num_cruce_unicos}")
# Out:
# Número de registros en df_matriculados: 547934
# Número de registros únicos en el cruce: 71931
